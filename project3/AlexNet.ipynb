# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

import os
import logging
import pandas as pd
import os.path as op
from PIL import Image, ImageOps
from pathlib import Path

from keras.models import load_model
from keras.utils import to_categorical, plot_model
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam, Adadelta
from sklearn.model_selection import train_test_split
from keras import backend as K
from matplotlib import pyplot as plt

import numpy as np

print(K.tensorflow_backend._get_available_gpus())
# Out:
# Using TensorFlow backend.
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
# Data properties
num_classes = 10
img_x, img_y = 128, 128

# %%
def load_train():
    train_images = pd.read_pickle('train_max_x')
    train_labels = pd.read_csv('train_max_y.csv').to_numpy()[:, 1]
    return train_images, train_labels

def load_test():
    return pd.read_pickle('test_max_x')

def predictions_to_csv(pred, filename):
#     if not op.isdir(RESULT_DIR):
#         os.makedirs(RESULT_DIR)
    res = pd.Series(pred, name='Label')
    submission = pd.concat([pd.Series(range(0, res.shape[0]), name='Id'), res], axis=1)
    submission.to_csv(filename, index=False)

# %%
# Load training data
train_images, train_labels = load_train()
x_train, x_valid, y_train, y_valid = train_test_split(train_images, train_labels, test_size=0.2, random_state=42, stratify=train_labels)

# %%
# Reshape and normalize images
x_train = x_train.reshape(x_train.shape[0], img_x, img_y, 1)
x_valid = x_valid.reshape(x_valid.shape[0], img_x, img_y, 1)
x_train = x_train.astype('float32')
x_valid = x_valid.astype('float32')
x_train /= 255.
x_valid /= 255.

# One-hot encode labels
y_train = to_categorical(y_train, num_classes)
y_valid = to_categorical(y_valid, num_classes)

print(f'Train images dim: {x_train.shape}')
print(f'Train labels dim:{y_train.shape}')
print(f'Validation images dim: {x_valid.shape}')
print(f'Validation labels dim:{y_valid.shape}')
# Out:
# Train images dim: (40000, 128, 128, 1)
# Train labels dim:(40000, 10)
# Validation images dim: (10000, 128, 128, 1)
# Validation labels dim:(10000, 10)

# %%
class AlexNet():
    def __init__(self, input_shape, num_classes, optimizer):
        self.model = Sequential()
        #layer1
        self.model.add(Conv2D(96, kernel_size=(11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
        self.model.add(BatchNormalization())
        self.model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

        #layer2
        self.model.add(Conv2D(256, kernel_size=(5, 5), strides=(1, 1), padding='same', activation='relu'))
        self.model.add(BatchNormalization())
        self.model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

        #layer3
        self.model.add(Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
        self.model.add(BatchNormalization())
        self.model.add(Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
        self.model.add(BatchNormalization())
        self.model.add(Conv2D(384, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu'))
        self.model.add(BatchNormalization())
        self.model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
        
        #fully connected layer
        self.model.add(Flatten())
        self.model.add(Dense(4096, activation='relu'))
        self.model.add(Dense(4096, activation='relu'))
        self.model.add(Dense(num_classes, activation='softmax'))

        self.model.compile(loss=keras.losses.categorical_crossentropy, optimizer=optimizer, metrics=['accuracy'])
        print(self.model.summary())

    def train(self, x, y, x_valid, y_valid, batch_size=64, epochs=60, datagen=True, num_steps='auto', callbacks=None):
        if num_steps == 'auto':
            num_steps = x.shape[0] // batch_size
        if datagen:
            data_generator = ImageDataGenerator(
                rotation_range=10,
                width_shift_range=0.1,
                height_shift_range=0.1,
                shear_range=1,
                zoom_range=0.1
            )
            self.history = self.model.fit_generator(
                data_generator.flow(x, y, batch_size=batch_size),
                steps_per_epoch=num_steps,
                epochs=epochs,
                verbose=1,
                validation_data=(x_valid, y_valid),
                callbacks=callbacks
            )
        else:
            self.history = self.model.fit(
                x, y,
                batch_size=batch_size,
                epochs=epochs,
                verbose=1,
                validation_data=(x_valid, y_valid),
                callbacks=callbacks
            )
        return self.history

    def evaluate(self, x, y):
        return self.model.evaluate(x, y, verbose=0)

    def predict(self, x):
        return self.model.predict(x)

    def save(self, filename):
        self.model.save(filename)

# %%
# optimizer = Adadelta()
optimizer = Adam()
# optimizer = Nadam()

# Train params
batch_size = 64
num_steps = 'auto'
# num_steps = 1000
epochs = 100
model_name = 'AlexNet'

# %%
# Callbacks
annealer = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.85)
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1)
checkpoint = ModelCheckpoint(
    filepath=f'./trained_models/{model_name}_best.h5',
    verbose=1,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    period=1)

# %%
model = AlexNet(input_shape=(img_x, img_y, 1), num_classes=num_classes, optimizer=optimizer)
plot_model(model.model, to_file='{model_name}_arch.png', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 96)        11712
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 96)        384
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 256)       614656
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 384)         885120
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 384)         1327488
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 384)         1327488
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 384)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1536)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              6295552
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 27,290,314
# Trainable params: 27,287,306
# Non-trainable params: 3,008
# _________________________________________________________________
# None

# %%
history = model.train(
    x_train, y_train,
    x_valid, y_valid,
    batch_size=batch_size,
    epochs=epochs,
    datagen=True,
    num_steps=num_steps,
    callbacks=[annealer, early_stop, checkpoint]
    )
# Out:
# Epoch 1/100
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1245 - accuracy: 0.2567 - val_loss: 1.9472 - val_accuracy: 0.2488
#
# Epoch 00001: val_accuracy improved from -inf to 0.24880, saving model to ./trained_models/AlexNet_best.h5
# Epoch 2/100
# 625/625 [==============================] - 48s 77ms/step - loss: 1.8442 - accuracy: 0.2928 - val_loss: 1.8217 - val_accuracy: 0.3109
#
# Epoch 00002: val_accuracy improved from 0.24880 to 0.31090, saving model to ./trained_models/AlexNet_best.h5
# Epoch 3/100
# 625/625 [==============================] - 48s 77ms/step - loss: 1.7621 - accuracy: 0.3207 - val_loss: 2.0609 - val_accuracy: 0.1865
#
# Epoch 00003: val_accuracy did not improve from 0.31090
# Epoch 4/100
# 625/625 [==============================] - 48s 77ms/step - loss: 1.6809 - accuracy: 0.3517 - val_loss: 1.9609 - val_accuracy: 0.3374
#
# Epoch 00004: val_accuracy improved from 0.31090 to 0.33740, saving model to ./trained_models/AlexNet_best.h5
# Epoch 5/100
# 625/625 [==============================] - 48s 77ms/step - loss: 1.5006 - accuracy: 0.4645 - val_loss: 1.3967 - val_accuracy: 0.5083
#
# Epoch 00005: val_accuracy improved from 0.33740 to 0.50830, saving model to ./trained_models/AlexNet_best.h5
# Epoch 6/100
# 625/625 [==============================] - 48s 77ms/step - loss: 1.2936 - accuracy: 0.5470 - val_loss: 1.1956 - val_accuracy: 0.5862
#
# Epoch 00006: val_accuracy improved from 0.50830 to 0.58620, saving model to ./trained_models/AlexNet_best.h5
# Epoch 7/100
# 625/625 [==============================] - 48s 76ms/step - loss: 1.1548 - accuracy: 0.5983 - val_loss: 1.7023 - val_accuracy: 0.5048
#
# Epoch 00007: val_accuracy did not improve from 0.58620
# Epoch 8/100
# 625/625 [==============================] - 48s 77ms/step - loss: 1.0473 - accuracy: 0.6383 - val_loss: 0.8856 - val_accuracy: 0.6910
#
# Epoch 00008: val_accuracy improved from 0.58620 to 0.69100, saving model to ./trained_models/AlexNet_best.h5
# Epoch 9/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.9781 - accuracy: 0.6637 - val_loss: 1.3665 - val_accuracy: 0.5317
#
# Epoch 00009: val_accuracy did not improve from 0.69100
# Epoch 10/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.9097 - accuracy: 0.6924 - val_loss: 0.8741 - val_accuracy: 0.6986
#
# Epoch 00010: val_accuracy improved from 0.69100 to 0.69860, saving model to ./trained_models/AlexNet_best.h5
# Epoch 11/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.8437 - accuracy: 0.7167 - val_loss: 0.7843 - val_accuracy: 0.7465
#
# Epoch 00011: val_accuracy improved from 0.69860 to 0.74650, saving model to ./trained_models/AlexNet_best.h5
# Epoch 12/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.7896 - accuracy: 0.7344 - val_loss: 1.1293 - val_accuracy: 0.6677
#
# Epoch 00012: val_accuracy did not improve from 0.74650
# Epoch 13/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.7508 - accuracy: 0.7471 - val_loss: 0.8122 - val_accuracy: 0.7094
#
# Epoch 00013: val_accuracy did not improve from 0.74650
# Epoch 14/100
# 625/625 [==============================] - 48s 76ms/step - loss: 0.7089 - accuracy: 0.7623 - val_loss: 0.9029 - val_accuracy: 0.6939
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
#
# Epoch 00014: val_accuracy did not improve from 0.74650
# Epoch 15/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.6732 - accuracy: 0.7729 - val_loss: 0.6234 - val_accuracy: 0.7935
#
# Epoch 00015: val_accuracy improved from 0.74650 to 0.79350, saving model to ./trained_models/AlexNet_best.h5
# Epoch 16/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.6470 - accuracy: 0.7823 - val_loss: 0.7347 - val_accuracy: 0.7487
#
# Epoch 00016: val_accuracy did not improve from 0.79350
# Epoch 17/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.6203 - accuracy: 0.7923 - val_loss: 0.6165 - val_accuracy: 0.7978
#
# Epoch 00017: val_accuracy improved from 0.79350 to 0.79780, saving model to ./trained_models/AlexNet_best.h5
# Epoch 18/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.6084 - accuracy: 0.7929 - val_loss: 0.5205 - val_accuracy: 0.8267
#
# Epoch 00018: val_accuracy improved from 0.79780 to 0.82670, saving model to ./trained_models/AlexNet_best.h5
# Epoch 19/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5954 - accuracy: 0.7984 - val_loss: 0.7100 - val_accuracy: 0.7649
#
# Epoch 00019: val_accuracy did not improve from 0.82670
# Epoch 20/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5754 - accuracy: 0.8067 - val_loss: 0.5945 - val_accuracy: 0.7985
#
# Epoch 00020: val_accuracy did not improve from 0.82670
# Epoch 21/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5705 - accuracy: 0.8056 - val_loss: 0.4848 - val_accuracy: 0.8388
#
# Epoch 00021: val_accuracy improved from 0.82670 to 0.83880, saving model to ./trained_models/AlexNet_best.h5
# Epoch 22/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5487 - accuracy: 0.8135 - val_loss: 0.5718 - val_accuracy: 0.8076
#
# Epoch 00022: val_accuracy did not improve from 0.83880
# Epoch 23/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5334 - accuracy: 0.8181 - val_loss: 0.6134 - val_accuracy: 0.8101
#
# Epoch 00023: val_accuracy did not improve from 0.83880
# Epoch 24/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5231 - accuracy: 0.8213 - val_loss: 0.6113 - val_accuracy: 0.8073
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0007225000590551645.
#
# Epoch 00024: val_accuracy did not improve from 0.83880
# Epoch 25/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.5011 - accuracy: 0.8282 - val_loss: 0.4640 - val_accuracy: 0.8498
#
# Epoch 00025: val_accuracy improved from 0.83880 to 0.84980, saving model to ./trained_models/AlexNet_best.h5
# Epoch 26/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4920 - accuracy: 0.8315 - val_loss: 0.4371 - val_accuracy: 0.8570
#
# Epoch 00026: val_accuracy improved from 0.84980 to 0.85700, saving model to ./trained_models/AlexNet_best.h5
# Epoch 27/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4826 - accuracy: 0.8352 - val_loss: 0.5383 - val_accuracy: 0.8325
#
# Epoch 00027: val_accuracy did not improve from 0.85700
# Epoch 28/100
# 625/625 [==============================] - 48s 78ms/step - loss: 0.4737 - accuracy: 0.8368 - val_loss: 0.5121 - val_accuracy: 0.8329
#
# Epoch 00028: val_accuracy did not improve from 0.85700
# Epoch 29/100
# 625/625 [==============================] - 48s 78ms/step - loss: 0.4597 - accuracy: 0.8424 - val_loss: 0.4065 - val_accuracy: 0.8674
#
# Epoch 00029: val_accuracy improved from 0.85700 to 0.86740, saving model to ./trained_models/AlexNet_best.h5
# Epoch 30/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4556 - accuracy: 0.8435 - val_loss: 0.4109 - val_accuracy: 0.8673
#
# Epoch 00030: val_accuracy did not improve from 0.86740
# Epoch 31/100
# 625/625 [==============================] - 48s 78ms/step - loss: 0.4539 - accuracy: 0.8407 - val_loss: 0.4373 - val_accuracy: 0.8620
#
# Epoch 00031: val_accuracy did not improve from 0.86740
# Epoch 32/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4379 - accuracy: 0.8490 - val_loss: 0.4303 - val_accuracy: 0.8592
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006141250254586339.
#
# Epoch 00032: val_accuracy did not improve from 0.86740
# Epoch 33/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4203 - accuracy: 0.8548 - val_loss: 0.4062 - val_accuracy: 0.8711
#
# Epoch 00033: val_accuracy improved from 0.86740 to 0.87110, saving model to ./trained_models/AlexNet_best.h5
# Epoch 34/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4035 - accuracy: 0.8602 - val_loss: 0.4994 - val_accuracy: 0.8442
#
# Epoch 00034: val_accuracy did not improve from 0.87110
# Epoch 35/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.4038 - accuracy: 0.8582 - val_loss: 0.4379 - val_accuracy: 0.8601
#
# Epoch 00035: val_accuracy did not improve from 0.87110
# Epoch 36/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3885 - accuracy: 0.8638 - val_loss: 0.4099 - val_accuracy: 0.8731
#
# Epoch 00036: val_accuracy improved from 0.87110 to 0.87310, saving model to ./trained_models/AlexNet_best.h5
# Epoch 37/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3860 - accuracy: 0.8658 - val_loss: 0.4203 - val_accuracy: 0.8714
#
# Epoch 00037: val_accuracy did not improve from 0.87310
# Epoch 38/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3747 - accuracy: 0.8696 - val_loss: 0.7344 - val_accuracy: 0.7862
#
# Epoch 00038: val_accuracy did not improve from 0.87310
# Epoch 39/100
# 625/625 [==============================] - 49s 78ms/step - loss: 0.3749 - accuracy: 0.8703 - val_loss: 0.4039 - val_accuracy: 0.8737
#
# Epoch 00039: val_accuracy improved from 0.87310 to 0.87370, saving model to ./trained_models/AlexNet_best.h5
# Epoch 40/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3645 - accuracy: 0.8731 - val_loss: 0.4065 - val_accuracy: 0.8767
#
# Epoch 00040: val_accuracy improved from 0.87370 to 0.87670, saving model to ./trained_models/AlexNet_best.h5
# Epoch 41/100
# 625/625 [==============================] - 49s 78ms/step - loss: 0.3559 - accuracy: 0.8778 - val_loss: 0.3963 - val_accuracy: 0.8779
#
# Epoch 00041: val_accuracy improved from 0.87670 to 0.87790, saving model to ./trained_models/AlexNet_best.h5
# Epoch 42/100
# 625/625 [==============================] - 49s 78ms/step - loss: 0.3499 - accuracy: 0.8776 - val_loss: 0.6163 - val_accuracy: 0.8182
#
# Epoch 00042: val_accuracy did not improve from 0.87790
# Epoch 43/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3424 - accuracy: 0.8795 - val_loss: 0.4191 - val_accuracy: 0.8759
#
# Epoch 00043: val_accuracy did not improve from 0.87790
# Epoch 44/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3384 - accuracy: 0.8803 - val_loss: 0.4863 - val_accuracy: 0.8503
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0005220062914304435.
#
# Epoch 00044: val_accuracy did not improve from 0.87790
# Epoch 45/100
# 625/625 [==============================] - 49s 78ms/step - loss: 0.3234 - accuracy: 0.8860 - val_loss: 0.4570 - val_accuracy: 0.8629
#
# Epoch 00045: val_accuracy did not improve from 0.87790
# Epoch 46/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.3200 - accuracy: 0.8871 - val_loss: 0.4360 - val_accuracy: 0.8761
#
# Epoch 00046: val_accuracy did not improve from 0.87790
# Epoch 47/100
# 625/625 [==============================] - 49s 78ms/step - loss: 0.3100 - accuracy: 0.8904 - val_loss: 0.5518 - val_accuracy: 0.8475
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
#
# Epoch 00047: val_accuracy did not improve from 0.87790
# Epoch 48/100
# 625/625 [==============================] - 48s 78ms/step - loss: 0.2940 - accuracy: 0.8949 - val_loss: 0.4452 - val_accuracy: 0.8707
#
# Epoch 00048: val_accuracy did not improve from 0.87790
# Epoch 49/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.2846 - accuracy: 0.8989 - val_loss: 0.4831 - val_accuracy: 0.8698
#
# Epoch 00049: val_accuracy did not improve from 0.87790
# Epoch 50/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.2879 - accuracy: 0.8988 - val_loss: 0.4494 - val_accuracy: 0.8670
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
#
# Epoch 00050: val_accuracy did not improve from 0.87790
# Epoch 51/100
# 625/625 [==============================] - 48s 77ms/step - loss: 0.2675 - accuracy: 0.9063 - val_loss: 0.5280 - val_accuracy: 0.8558
#
# Epoch 00051: val_accuracy did not improve from 0.87790
# Epoch 00051: early stopping

# %%
model = load_model(f'./trained_models/{model_name}_best.h5')
score = model.evaluate(x_valid, y_valid)
# Out:
# 10000/10000 [==============================] - 3s 276us/step

# %%
print(f'Validation Loss: {score[0]}')
print(f'Validation Accuracy: {score[1]}')
# Out:
# Validation Loss: 0.39626205382347107
# Validation Accuracy: 0.8779000043869019

# %%
history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

if score[1] >= 0.97:
    model.save(f'./trained_models/{model_name}_{round(score[1]*100, 2)}%.h5')
else:
    print('Model did not exceed baseline validation accuracy, not saving.')
# Out:
# Model did not exceed baseline validation accuracy, not saving.

# %%
epcs = range(1, len(acc) + 1)
plt.plot(epcs, acc, 'bo', label='Training acc')
plt.plot(epcs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(f'./figures/{model_name}_{round(score[1]*100, 2)}%.png')
plt.show()

# %%
x_test = load_test()
x_test = x_test.reshape(x_test.shape[0], img_x, img_y, 1)
x_test = x_test.astype('float32')
x_test /= 255.
print('Test dim: ', x_test.shape)
# Out:
# Test dim:  (10000, 128, 128, 1)

# %%
# Generate test labels
import numpy as np
y_test = model.predict(x_test)
y_test = np.argmax(y_test, axis=1)
print(y_test.shape)
predictions_to_csv(y_test, f'{model_name}_pred.csv')
# Out:
# (10000,)
