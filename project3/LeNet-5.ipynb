# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator

import os
import logging
import pandas as pd
import os.path as op
from PIL import Image, ImageOps
from pathlib import Path

from keras.models import load_model
from keras.utils import to_categorical, plot_model
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam, Adadelta
from sklearn.model_selection import train_test_split
from keras import backend as K
from matplotlib import pyplot as plt

import numpy as np

print(K.tensorflow_backend._get_available_gpus())
# Out:
# Using TensorFlow backend.
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
# Data properties
num_classes = 10
img_x, img_y = 128, 128

# %%
def load_train():
    train_images = pd.read_pickle('train_max_x')
    train_labels = pd.read_csv('train_max_y.csv').to_numpy()[:, 1]
    return train_images, train_labels

def load_test():
    return pd.read_pickle('test_max_x')

def predictions_to_csv(pred, filename):
#     if not op.isdir(RESULT_DIR):
#         os.makedirs(RESULT_DIR)
    res = pd.Series(pred, name='Label')
    submission = pd.concat([pd.Series(range(0, res.shape[0]), name='Id'), res], axis=1)
    submission.to_csv(filename, index=False)

# %%
# Load training data
train_images, train_labels = load_train()
x_train, x_valid, y_train, y_valid = train_test_split(train_images, train_labels, test_size=0.2, random_state=42, stratify=train_labels)

# %%
# Reshape and normalize images
x_train = x_train.reshape(x_train.shape[0], img_x, img_y, 1)
x_valid = x_valid.reshape(x_valid.shape[0], img_x, img_y, 1)
x_train = x_train.astype('float32')
x_valid = x_valid.astype('float32')
x_train /= 255.
x_valid /= 255.

# One-hot encode labels
y_train = to_categorical(y_train, num_classes)
y_valid = to_categorical(y_valid, num_classes)

print(f'Train images dim: {x_train.shape}')
print(f'Train labels dim:{y_train.shape}')
print(f'Validation images dim: {x_valid.shape}')
print(f'Validation labels dim:{y_valid.shape}')
# Out:
# Train images dim: (40000, 128, 128, 1)
# Train labels dim:(40000, 10)
# Validation images dim: (10000, 128, 128, 1)
# Validation labels dim:(10000, 10)

# %%
class LeNet():
    def __init__(self, input_shape, num_classes, optimizer):
        self.model = Sequential()
        #layer1
        self.model.add(Conv2D(16, kernel_size=(5, 5), padding='same', activation='relu', input_shape=input_shape))
        self.model.add(BatchNormalization())
        self.model.add(Conv2D(16, kernel_size=(5, 5), padding='same', activation='relu', input_shape=input_shape))
        self.model.add(BatchNormalization())
        self.model.add(MaxPooling2D(pool_size=(2, 2)))

        #layer2
        self.model.add(Conv2D(36, kernel_size=(5, 5), padding='same', activation='relu'))
        self.model.add(BatchNormalization())
        self.model.add(Conv2D(36, kernel_size=(5, 5), padding='same', activation='relu'))
        self.model.add(BatchNormalization())
        self.model.add(MaxPooling2D(pool_size=(2, 2)))

        #fully connected layer
        self.model.add(Flatten())
        self.model.add(Dense(512, activation='relu'))
        self.model.add(Dense(256, activation='relu'))
        self.model.add(Dropout(0.5))
        self.model.add(Dense(num_classes, activation='softmax'))

        self.model.compile(loss=keras.losses.categorical_crossentropy, optimizer=optimizer, metrics=['accuracy'])
        print(self.model.summary())

    def train(self, x, y, x_valid, y_valid, batch_size=64, epochs=60, datagen=True, num_steps='auto', callbacks=None):
        if num_steps == 'auto':
            num_steps = x.shape[0] // batch_size
        if datagen:
            data_generator = ImageDataGenerator(
                rotation_range=10,
                width_shift_range=0.1,
                height_shift_range=0.1,
                shear_range=1,
                zoom_range=0.1
            )
            self.history = self.model.fit_generator(
                data_generator.flow(x, y, batch_size=batch_size),
                steps_per_epoch=num_steps,
                epochs=epochs,
                verbose=1,
                validation_data=(x_valid, y_valid),
                callbacks=callbacks
            )
        else:
            self.history = self.model.fit(
                x, y,
                batch_size=batch_size,
                epochs=epochs,
                verbose=1,
                validation_data=(x_valid, y_valid),
                callbacks=callbacks
            )
        return self.history

    def evaluate(self, x, y):
        return self.model.evaluate(x, y, verbose=0)

    def predict(self, x):
        return self.model.predict(x)

    def save(self, filename):
        self.model.save(filename)

# %%
# optimizer = Adadelta()
optimizer = Adam()
# optimizer = Nadam()

# Train params
batch_size = 64
num_steps = 'auto'
# num_steps = 1000
epochs = 100
model_name = 'LeNet-5'

# %%
# Callbacks
annealer = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.85)
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1)
checkpoint = ModelCheckpoint(
    filepath=f'./trained_models/{model_name}_best.h5',
    verbose=1,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    period=1)

# %%
model = LeNet(input_shape=(img_x, img_y, 1), num_classes=num_classes, optimizer=optimizer)
plot_model(model.model, to_file='{model_name}_arch.png', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 124, 124, 16)      416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 124, 124, 16)      64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 120, 120, 16)      6416
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 120, 120, 16)      64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 60, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 36)        14436
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 56, 56, 36)        144
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 52, 52, 36)        32436
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 52, 52, 36)        144
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 36)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 24336)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               12460544
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 12,648,562
# Trainable params: 12,648,354
# Non-trainable params: 208
# _________________________________________________________________
# None

# %%
history = model.train(
    x_train, y_train,
    x_valid, y_valid,
    batch_size=batch_size,
    epochs=epochs,
    datagen=True,
    num_steps=num_steps,
    callbacks=[annealer, early_stop, checkpoint]
    )
# Out:
# Epoch 1/100
# 625/625 [==============================] - 71s 114ms/step - loss: 2.2003 - accuracy: 0.2485 - val_loss: 1.9011 - val_accuracy: 0.2647
#
# Epoch 00001: val_accuracy improved from -inf to 0.26470, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 2/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.9270 - accuracy: 0.2665 - val_loss: 1.8930 - val_accuracy: 0.2695
#
# Epoch 00002: val_accuracy improved from 0.26470 to 0.26950, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 3/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.9094 - accuracy: 0.2671 - val_loss: 1.8963 - val_accuracy: 0.2690
#
# Epoch 00003: val_accuracy did not improve from 0.26950
# Epoch 4/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.9011 - accuracy: 0.2678 - val_loss: 1.8918 - val_accuracy: 0.2687
#
# Epoch 00004: val_accuracy did not improve from 0.26950
# Epoch 5/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.9028 - accuracy: 0.2666 - val_loss: 1.8903 - val_accuracy: 0.2688
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
#
# Epoch 00005: val_accuracy did not improve from 0.26950
# Epoch 6/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.8946 - accuracy: 0.2679 - val_loss: 1.8946 - val_accuracy: 0.2690
#
# Epoch 00006: val_accuracy did not improve from 0.26950
# Epoch 7/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.8932 - accuracy: 0.2690 - val_loss: 1.8899 - val_accuracy: 0.2689
#
# Epoch 00007: val_accuracy did not improve from 0.26950
# Epoch 8/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.8904 - accuracy: 0.2688 - val_loss: 1.8857 - val_accuracy: 0.2691
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0007225000590551645.
#
# Epoch 00008: val_accuracy did not improve from 0.26950
# Epoch 9/100
# 625/625 [==============================] - 66s 105ms/step - loss: 1.8692 - accuracy: 0.2747 - val_loss: 1.8641 - val_accuracy: 0.2749
#
# Epoch 00009: val_accuracy improved from 0.26950 to 0.27490, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 10/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.7257 - accuracy: 0.3167 - val_loss: 1.5786 - val_accuracy: 0.4077
#
# Epoch 00010: val_accuracy improved from 0.27490 to 0.40770, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 11/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.5936 - accuracy: 0.3830 - val_loss: 1.4961 - val_accuracy: 0.4413
#
# Epoch 00011: val_accuracy improved from 0.40770 to 0.44130, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 12/100
# 625/625 [==============================] - 66s 106ms/step - loss: 1.5202 - accuracy: 0.4168 - val_loss: 1.5205 - val_accuracy: 0.4546
#
# Epoch 00012: val_accuracy improved from 0.44130 to 0.45460, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 13/100
# 625/625 [==============================] - 66s 105ms/step - loss: 1.4711 - accuracy: 0.4397 - val_loss: 1.3639 - val_accuracy: 0.4972
#
# Epoch 00013: val_accuracy improved from 0.45460 to 0.49720, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 14/100
# 625/625 [==============================] - 66s 105ms/step - loss: 1.4247 - accuracy: 0.4695 - val_loss: 1.3136 - val_accuracy: 0.5086
#
# Epoch 00014: val_accuracy improved from 0.49720 to 0.50860, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 15/100
# 625/625 [==============================] - 67s 107ms/step - loss: 1.3448 - accuracy: 0.5199 - val_loss: 1.1173 - val_accuracy: 0.6117
#
# Epoch 00015: val_accuracy improved from 0.50860 to 0.61170, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 16/100
# 625/625 [==============================] - 67s 108ms/step - loss: 1.2222 - accuracy: 0.5738 - val_loss: 1.1183 - val_accuracy: 0.5986
#
# Epoch 00016: val_accuracy did not improve from 0.61170
# Epoch 17/100
# 625/625 [==============================] - 67s 108ms/step - loss: 1.1827 - accuracy: 0.5998 - val_loss: 0.9608 - val_accuracy: 0.6923
#
# Epoch 00017: val_accuracy improved from 0.61170 to 0.69230, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 18/100
# 625/625 [==============================] - 67s 108ms/step - loss: 1.0551 - accuracy: 0.6494 - val_loss: 0.7915 - val_accuracy: 0.7259
#
# Epoch 00018: val_accuracy improved from 0.69230 to 0.72590, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 19/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.9280 - accuracy: 0.6910 - val_loss: 0.6878 - val_accuracy: 0.7695
#
# Epoch 00019: val_accuracy improved from 0.72590 to 0.76950, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 20/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.8448 - accuracy: 0.7195 - val_loss: 0.6590 - val_accuracy: 0.7700
#
# Epoch 00020: val_accuracy improved from 0.76950 to 0.77000, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 21/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.7856 - accuracy: 0.7394 - val_loss: 0.6650 - val_accuracy: 0.7631
#
# Epoch 00021: val_accuracy did not improve from 0.77000
# Epoch 22/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.7362 - accuracy: 0.7605 - val_loss: 0.8432 - val_accuracy: 0.7241
#
# Epoch 00022: val_accuracy did not improve from 0.77000
# Epoch 23/100
# 625/625 [==============================] - 66s 106ms/step - loss: 0.7034 - accuracy: 0.7707 - val_loss: 0.5518 - val_accuracy: 0.8251
#
# Epoch 00023: val_accuracy improved from 0.77000 to 0.82510, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 24/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.6575 - accuracy: 0.7894 - val_loss: 0.5300 - val_accuracy: 0.8399
#
# Epoch 00024: val_accuracy improved from 0.82510 to 0.83990, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 25/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.6200 - accuracy: 0.8032 - val_loss: 0.4791 - val_accuracy: 0.8517
#
# Epoch 00025: val_accuracy improved from 0.83990 to 0.85170, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 26/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.5924 - accuracy: 0.8161 - val_loss: 0.4478 - val_accuracy: 0.8570
#
# Epoch 00026: val_accuracy improved from 0.85170 to 0.85700, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 27/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.5675 - accuracy: 0.8238 - val_loss: 0.4638 - val_accuracy: 0.8545
#
# Epoch 00027: val_accuracy did not improve from 0.85700
# Epoch 28/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.5549 - accuracy: 0.8306 - val_loss: 0.3934 - val_accuracy: 0.8806
#
# Epoch 00028: val_accuracy improved from 0.85700 to 0.88060, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 29/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.5281 - accuracy: 0.8370 - val_loss: 0.4823 - val_accuracy: 0.8663
#
# Epoch 00029: val_accuracy did not improve from 0.88060
# Epoch 30/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.5074 - accuracy: 0.8456 - val_loss: 0.3471 - val_accuracy: 0.8947
#
# Epoch 00030: val_accuracy improved from 0.88060 to 0.89470, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 31/100
# 625/625 [==============================] - 66s 106ms/step - loss: 0.4909 - accuracy: 0.8512 - val_loss: 0.3941 - val_accuracy: 0.8830
#
# Epoch 00031: val_accuracy did not improve from 0.89470
# Epoch 32/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.4680 - accuracy: 0.8575 - val_loss: 0.4172 - val_accuracy: 0.8774
#
# Epoch 00032: val_accuracy did not improve from 0.89470
# Epoch 33/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.4633 - accuracy: 0.8601 - val_loss: 0.3307 - val_accuracy: 0.9047
#
# Epoch 00033: val_accuracy improved from 0.89470 to 0.90470, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 34/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.4535 - accuracy: 0.8629 - val_loss: 0.5407 - val_accuracy: 0.8527
#
# Epoch 00034: val_accuracy did not improve from 0.90470
# Epoch 35/100
# 625/625 [==============================] - 67s 108ms/step - loss: 0.4465 - accuracy: 0.8645 - val_loss: 0.3752 - val_accuracy: 0.8865
#
# Epoch 00035: val_accuracy did not improve from 0.90470
# Epoch 36/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.4329 - accuracy: 0.8700 - val_loss: 0.2883 - val_accuracy: 0.9133
#
# Epoch 00036: val_accuracy improved from 0.90470 to 0.91330, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 37/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.4200 - accuracy: 0.8745 - val_loss: 0.4511 - val_accuracy: 0.8909
#
# Epoch 00037: val_accuracy did not improve from 0.91330
# Epoch 38/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.4098 - accuracy: 0.8776 - val_loss: 0.3347 - val_accuracy: 0.9040
#
# Epoch 00038: val_accuracy did not improve from 0.91330
# Epoch 39/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3964 - accuracy: 0.8779 - val_loss: 0.2569 - val_accuracy: 0.9250
#
# Epoch 00039: val_accuracy improved from 0.91330 to 0.92500, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 40/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3934 - accuracy: 0.8813 - val_loss: 0.3272 - val_accuracy: 0.9100
#
# Epoch 00040: val_accuracy did not improve from 0.92500
# Epoch 41/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3859 - accuracy: 0.8831 - val_loss: 0.2804 - val_accuracy: 0.9162
#
# Epoch 00041: val_accuracy did not improve from 0.92500
# Epoch 42/100
# 625/625 [==============================] - 66s 106ms/step - loss: 0.3878 - accuracy: 0.8812 - val_loss: 0.3024 - val_accuracy: 0.9230
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0006141250254586339.
#
# Epoch 00042: val_accuracy did not improve from 0.92500
# Epoch 43/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3657 - accuracy: 0.8879 - val_loss: 0.2625 - val_accuracy: 0.9340
#
# Epoch 00043: val_accuracy improved from 0.92500 to 0.93400, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 44/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3635 - accuracy: 0.8903 - val_loss: 0.2664 - val_accuracy: 0.9280
#
# Epoch 00044: val_accuracy did not improve from 0.93400
# Epoch 45/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3530 - accuracy: 0.8931 - val_loss: 0.2512 - val_accuracy: 0.9397
#
# Epoch 00045: val_accuracy improved from 0.93400 to 0.93970, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 46/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3454 - accuracy: 0.8956 - val_loss: 0.2800 - val_accuracy: 0.9188
#
# Epoch 00046: val_accuracy did not improve from 0.93970
# Epoch 47/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3343 - accuracy: 0.8974 - val_loss: 0.2715 - val_accuracy: 0.9347
#
# Epoch 00047: val_accuracy did not improve from 0.93970
# Epoch 48/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3383 - accuracy: 0.8975 - val_loss: 0.2334 - val_accuracy: 0.9409
#
# Epoch 00048: val_accuracy improved from 0.93970 to 0.94090, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 49/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3347 - accuracy: 0.8991 - val_loss: 0.2788 - val_accuracy: 0.9290
#
# Epoch 00049: val_accuracy did not improve from 0.94090
# Epoch 50/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3378 - accuracy: 0.8961 - val_loss: 0.2585 - val_accuracy: 0.9308
#
# Epoch 00050: val_accuracy did not improve from 0.94090
# Epoch 51/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3278 - accuracy: 0.9022 - val_loss: 0.2269 - val_accuracy: 0.9425
#
# Epoch 00051: val_accuracy improved from 0.94090 to 0.94250, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 52/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3187 - accuracy: 0.9045 - val_loss: 0.2262 - val_accuracy: 0.9412
#
# Epoch 00052: val_accuracy did not improve from 0.94250
# Epoch 53/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3205 - accuracy: 0.9043 - val_loss: 0.2365 - val_accuracy: 0.9393
#
# Epoch 00053: val_accuracy did not improve from 0.94250
# Epoch 54/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3171 - accuracy: 0.9039 - val_loss: 0.2770 - val_accuracy: 0.9364
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0005220062914304435.
#
# Epoch 00054: val_accuracy did not improve from 0.94250
# Epoch 55/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3089 - accuracy: 0.9064 - val_loss: 0.4852 - val_accuracy: 0.8654
#
# Epoch 00055: val_accuracy did not improve from 0.94250
# Epoch 56/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3002 - accuracy: 0.9093 - val_loss: 0.2177 - val_accuracy: 0.9464
#
# Epoch 00056: val_accuracy improved from 0.94250 to 0.94640, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 57/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3023 - accuracy: 0.9081 - val_loss: 0.2669 - val_accuracy: 0.9451
#
# Epoch 00057: val_accuracy did not improve from 0.94640
# Epoch 58/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.3034 - accuracy: 0.9086 - val_loss: 0.2528 - val_accuracy: 0.9399
#
# Epoch 00058: val_accuracy did not improve from 0.94640
# Epoch 59/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2954 - accuracy: 0.9119 - val_loss: 0.2693 - val_accuracy: 0.9315
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
#
# Epoch 00059: val_accuracy did not improve from 0.94640
# Epoch 60/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2775 - accuracy: 0.9156 - val_loss: 0.2071 - val_accuracy: 0.9462
#
# Epoch 00060: val_accuracy did not improve from 0.94640
# Epoch 61/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2762 - accuracy: 0.9167 - val_loss: 0.2201 - val_accuracy: 0.9393
#
# Epoch 00061: val_accuracy did not improve from 0.94640
# Epoch 62/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2744 - accuracy: 0.9171 - val_loss: 0.2335 - val_accuracy: 0.9403
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
#
# Epoch 00062: val_accuracy did not improve from 0.94640
# Epoch 63/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2722 - accuracy: 0.9175 - val_loss: 0.2318 - val_accuracy: 0.9456
#
# Epoch 00063: val_accuracy did not improve from 0.94640
# Epoch 64/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2630 - accuracy: 0.9220 - val_loss: 0.2262 - val_accuracy: 0.9498
#
# Epoch 00064: val_accuracy improved from 0.94640 to 0.94980, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 65/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2640 - accuracy: 0.9190 - val_loss: 0.2208 - val_accuracy: 0.9493
#
# Epoch 00065: val_accuracy did not improve from 0.94980
# Epoch 66/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2623 - accuracy: 0.9204 - val_loss: 0.2238 - val_accuracy: 0.9399
#
# Epoch 00066: val_accuracy did not improve from 0.94980
# Epoch 67/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2579 - accuracy: 0.9214 - val_loss: 0.2432 - val_accuracy: 0.9442
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.0003205771208740771.
#
# Epoch 00067: val_accuracy did not improve from 0.94980
# Epoch 68/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2529 - accuracy: 0.9216 - val_loss: 0.2079 - val_accuracy: 0.9530
#
# Epoch 00068: val_accuracy improved from 0.94980 to 0.95300, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 69/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2504 - accuracy: 0.9220 - val_loss: 0.2132 - val_accuracy: 0.9502
#
# Epoch 00069: val_accuracy did not improve from 0.95300
# Epoch 70/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2476 - accuracy: 0.9239 - val_loss: 0.2336 - val_accuracy: 0.9486
#
# Epoch 00070: val_accuracy did not improve from 0.95300
# Epoch 71/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2444 - accuracy: 0.9245 - val_loss: 0.2148 - val_accuracy: 0.9522
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 0.0002724905527429655.
#
# Epoch 00071: val_accuracy did not improve from 0.95300
# Epoch 72/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2407 - accuracy: 0.9260 - val_loss: 0.2221 - val_accuracy: 0.9521
#
# Epoch 00072: val_accuracy did not improve from 0.95300
# Epoch 73/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2349 - accuracy: 0.9269 - val_loss: 0.2017 - val_accuracy: 0.9546
#
# Epoch 00073: val_accuracy improved from 0.95300 to 0.95460, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 74/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2341 - accuracy: 0.9281 - val_loss: 0.2324 - val_accuracy: 0.9499
#
# Epoch 00074: val_accuracy did not improve from 0.95460
# Epoch 75/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2339 - accuracy: 0.9277 - val_loss: 0.2303 - val_accuracy: 0.9549
#
# Epoch 00075: val_accuracy improved from 0.95460 to 0.95490, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 76/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2395 - accuracy: 0.9267 - val_loss: 0.2236 - val_accuracy: 0.9507
#
# Epoch 00076: val_accuracy did not improve from 0.95490
# Epoch 77/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2360 - accuracy: 0.9276 - val_loss: 0.2667 - val_accuracy: 0.9513
#
# Epoch 00077: val_accuracy did not improve from 0.95490
# Epoch 78/100
# 625/625 [==============================] - 66s 106ms/step - loss: 0.2315 - accuracy: 0.9294 - val_loss: 0.2207 - val_accuracy: 0.9580
#
# Epoch 00078: val_accuracy improved from 0.95490 to 0.95800, saving model to ./trained_models/LeNet-5_best.h5
# Epoch 79/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2297 - accuracy: 0.9294 - val_loss: 0.2435 - val_accuracy: 0.9487
#
# Epoch 00079: val_accuracy did not improve from 0.95800
# Epoch 80/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2329 - accuracy: 0.9286 - val_loss: 0.2118 - val_accuracy: 0.9545
#
# Epoch 00080: val_accuracy did not improve from 0.95800
# Epoch 81/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2282 - accuracy: 0.9293 - val_loss: 0.2625 - val_accuracy: 0.9530
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 0.00023161696735769509.
#
# Epoch 00081: val_accuracy did not improve from 0.95800
# Epoch 82/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2237 - accuracy: 0.9317 - val_loss: 0.2339 - val_accuracy: 0.9552
#
# Epoch 00082: val_accuracy did not improve from 0.95800
# Epoch 83/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2177 - accuracy: 0.9323 - val_loss: 0.2513 - val_accuracy: 0.9556
#
# Epoch 00083: val_accuracy did not improve from 0.95800
# Epoch 84/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2197 - accuracy: 0.9321 - val_loss: 0.2649 - val_accuracy: 0.9531
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.00019687442472786642.
#
# Epoch 00084: val_accuracy did not improve from 0.95800
# Epoch 85/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2187 - accuracy: 0.9316 - val_loss: 0.2437 - val_accuracy: 0.9562
#
# Epoch 00085: val_accuracy did not improve from 0.95800
# Epoch 86/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2059 - accuracy: 0.9359 - val_loss: 0.2760 - val_accuracy: 0.9554
#
# Epoch 00086: val_accuracy did not improve from 0.95800
# Epoch 87/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2146 - accuracy: 0.9344 - val_loss: 0.2368 - val_accuracy: 0.9564
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 0.00016734325545257888.
#
# Epoch 00087: val_accuracy did not improve from 0.95800
# Epoch 88/100
# 625/625 [==============================] - 67s 107ms/step - loss: 0.2142 - accuracy: 0.9332 - val_loss: 0.2492 - val_accuracy: 0.9526
#
# Epoch 00088: val_accuracy did not improve from 0.95800
# Epoch 00088: early stopping

# %%
model = load_model(f'./trained_models/{model_name}_best.h5')
score = model.evaluate(x_valid, y_valid)
# Out:
# 10000/10000 [==============================] - 5s 510us/step

# %%
print(f'Validation Loss: {score[0]}')
print(f'Validation Accuracy: {score[1]}')
# Out:
# Validation Loss: 0.22069263548254967
# Validation Accuracy: 0.9580000042915344

# %%
history_dict = history.history
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

if score[1] >= 0.97:
    model.save(f'./trained_models/{model_name}_{round(score[1]*100, 2)}%.h5')
else:
    print('Model did not exceed baseline validation accuracy, not saving.')
# Out:
# Model did not exceed baseline validation accuracy, not saving.

# %%
epcs = range(1, len(acc) + 1)
plt.plot(epcs, acc, 'bo', label='Training acc')
plt.plot(epcs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig(f'./figures/{model_name}_{round(score[1]*100, 2)}%.png')
plt.show()

# %%
x_test = load_test()
x_test = x_test.reshape(x_test.shape[0], img_x, img_y, 1)
x_test = x_test.astype('float32')
x_test /= 255.
print('Test dim: ', x_test.shape)
# Out:
# Test dim:  (10000, 128, 128, 1)

# %%
# Generate test labels
import numpy as np
y_test = model.predict(x_test)
y_test = np.argmax(y_test, axis=1)
print(y_test.shape)
predictions_to_csv(y_test, f'{model_name}_pred.csv')
# Out:
# (10000,)
